# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
diabetes = datasets.load_diabetes()
diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
diabetes.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
X = diabetes.data
Y = diabetes.target

# %%
X.shape, Y.shape
# Out:
# ((442, 10), (442,))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, RidgeCV, Lasso
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # L1 , L2 , L3

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=43)

print("The dimension of X_train is {}".format(X_train.shape))
print("The dimension of X_test is {}".format(X_test.shape))
#Scale features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# The dimension of X_train is (309, 10)
# The dimension of X_test is (133, 10)

# %%
#Model
lr = LinearRegression()

#Fit model
lr.fit(X_train, y_train)

#predict
#prediction = lr.predict(X_test)

#actual
actual = y_test

train_score_lr = lr.score(X_train, y_train)
test_score_lr = lr.score(X_test, y_test)

print("The train score for lr model is {}".format(train_score_lr))
print("The test score for lr model is {}".format(test_score_lr))


#Ridge Regression Model
ridgeReg = Ridge(alpha=10)

ridgeReg.fit(X_train,y_train)

#train and test scorefor ridge regression
train_score_ridge = ridgeReg.score(X_train, y_train)
test_score_ridge = ridgeReg.score(X_test, y_test)

print("\nRidge Model............................................\n")
print("The train score for ridge model is {}".format(train_score_ridge))
print("The test score for ridge model is {}".format(test_score_ridge))
# Out:
# The train score for lr model is 0.52768432526779
# The test score for lr model is 0.4816506895496182
#
# Ridge Model............................................
#
# The train score for ridge model is 0.5240060761334842
# The test score for ridge model is 0.48449878145328873

# %%
#Lasso regression model
print("\nLasso Model............................................\n")
lasso = Lasso(alpha = 10)
lasso.fit(X_train,y_train)
train_score_ls =lasso.score(X_train,y_train)
test_score_ls =lasso.score(X_test,y_test)

print("The train score for ls model is {}".format(train_score_ls))
print("The test score for ls model is {}".format(test_score_ls))
# Out:
# Lasso Model............................................
#
# The train score for ls model is 0.4660390628419778
# The test score for ls model is 0.42195764631506827

# %%
#Using the linear CV model
from sklearn.linear_model import LassoCV

#Lasso Cross validation
lasso_cv = LassoCV(alphas = [0.0001, 0.001,0.01, 0.1, 1, 10], random_state=0).fit(X_train, y_train)


#score
print(lasso_cv.score(X_train, y_train))
print(lasso_cv.score(X_test, y_test))
# Out:
# 0.5223338876547268
# 0.4840173038560459

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(X,Y,test_size=0.3,random_state=99)
train_x.shape, train_y.shape
# Out:
# ((309, 10), (309,))

# %%
from sklearn.linear_model import LinearRegression
le = LinearRegression()
le.fit(train_x,train_y)
y_pred = le.predict(test_x)
y_pred
# Out:
# array([ 77.9991034 , 170.44712136, 109.03660582, 223.84307065,
#         87.38430375, 211.46934588, 223.65994161,  52.81888351,
#        149.39008619, 294.9893952 , 127.72956377, 182.90399415,
#        102.6375881 , 144.69460471, 171.5213581 , 266.17922455,
#        201.8877034 , 166.18209687, 103.67082991, 169.01866852,
#        187.13785171, 130.10161695, 151.54411583, 156.45841795,
#        121.85578431, 304.14149903, 126.55107098, 158.76430506,
#        249.42202516, 154.22310276, 180.85528758, 180.06909853,
#        182.96467155, 200.00132316,  73.87031841, 146.19357531,
#        165.52522033, 160.93215348, 247.99028596, 210.37177183,
#         85.69905264, 211.07539533, 188.10590426, 119.60434815,
#        151.80766971, 188.31163328, 185.69251949, 168.92581539,
#        291.55993431, 248.60092291, 170.17035216, 208.5515447 ,
#         59.08071813, 195.30432554, 190.19923551, 149.97489689,
#        114.4835119 , 244.83078249, 254.54782428, 138.88949628,
# ...

# %%
result = pd.DataFrame({'Actual': test_y, 'Predict' : y_pred})
result
# Out:
#      Actual     Predict
# 0      75.0   77.999103
# 1     128.0  170.447121
# 2     125.0  109.036606
# 3     332.0  223.843071
# 4      37.0   87.384304
# ..      ...         ...
# 128    48.0  202.349391
# 129   172.0  144.663523
# 130    51.0   82.400892
# 131   277.0  185.443544
# 132    94.0  101.563213
#
# [133 rows x 2 columns]

# %%
print('coefficient', le.coef_)
print('intercept', le.intercept_)
# Out:
# coefficient [  40.66179183 -313.2934701   517.18345014  386.06561935 -604.64289258
#   275.31448303    3.92015562  172.39101348  661.95332633   62.26068823]
# intercept 155.59120125597175

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(test_y,y_pred)
# Out:
# 3157.972848565651

# %%
r2_score(test_y,y_pred)
# Out:
# 0.4545709909725648

# %%
# prompt: i need to pre process this data doing preprocessing to level up the accuracy
train_x, test_x, train_y, test_y = train_test_split(X,Y,test_size=0.3,random_state=99)


# Preprocess the data using MinMaxScaler
scaler = MinMaxScaler()
train_x = scaler.fit_transform(train_x)
test_x = scaler.transform(test_x)

# %%
le_improved = LinearRegression()
le_improved.fit(train_x, train_y)
y_pred = le_improved.predict(test_x)

# %%
print('coefficient', le.coef_)
print('intercept', le_improved.intercept_)
print('Mean Squared Error:', mean_squared_error(test_y, y_pred))
print('R-squared:', r2_score(test_y, y_pred))
# Out:
# coefficient [  40.66179183 -313.2934701   517.18345014  386.06561935 -604.64289258
#   275.31448303    3.92015562  172.39101348  661.95332633   62.26068823]
# intercept 17.196833756995346
# Mean Squared Error: 3157.972848565652
# R-squared: 0.4545709909725646

# %%
result = pd.DataFrame({'Actual': test_y, 'Predict': y_pred})
result
# Out:
#      Actual     Predict
# 0      75.0   77.999103
# 1     128.0  170.447121
# 2     125.0  109.036606
# 3     332.0  223.843071
# 4      37.0   87.384304
# ..      ...         ...
# 128    48.0  202.349391
# 129   172.0  144.663523
# 130    51.0   82.400892
# 131   277.0  185.443544
# 132    94.0  101.563213
#
# [133 rows x 2 columns]

# %%
X.shape, Y.shape
# Out:
# ((442, 10), (442,))

# %%
train_x2, test_x2, train_y2, test_y2 = train_test_split(X, Y, test_size=0.3, random_state=99, shuffle=True)
train_x2.shape, train_y2.shape
# Out:
# ((309, 10), (309,))

# %%
scaler_X = MinMaxScaler()  # Create a scaler for X
train_x2 = scaler_X.fit_transform(train_x2)  # Fit and transform training data
test_x2 = scaler_X.transform(test_x2)

# %%
# Create a separate scaler for Y
scaler_Y = MinMaxScaler()

# Reshape Y for scaling (MinMaxScaler expects 2D input)
train_y2 = train_y2.reshape(-1, 1)
test_y2 = test_y2.reshape(-1, 1)

# Fit and transform training target data
train_y2 = scaler_Y.fit_transform(train_y2)

# Transform test target data using the same scale
test_y2 = scaler_Y.transform(test_y2)

# %%
le_improved = LinearRegression()
le_improved.fit(train_x2, train_y2)
y_pred2 = le_improved.predict(test_x2)

# %%
result = pd.DataFrame({'Actual': test_y2.ravel(), 'Predict': y_pred2.ravel()})
print(result)
# Out:
#        Actual   Predict
# 0    0.155763  0.165106
# 1    0.320872  0.453106
# 2    0.311526  0.261796
# 3    0.956386  0.619449
# 4    0.037383  0.194344
# ..        ...       ...
# 128  0.071651  0.552490
# 129  0.457944  0.372784
# 130  0.080997  0.178819
# 131  0.785047  0.499824
# 132  0.214953  0.238515
#
# [133 rows x 2 columns]

# %%
print('coefficient', le_improved.coef_)
print('intercept', le_improved.intercept_)
# Out:
# coefficient [[ 0.02576794 -0.09303328  0.40461181  0.29399007 -0.52613054  0.26723749
#    0.00341706  0.14050617  0.53553138  0.04659702]]
# intercept [-0.02430893]

# %%
print('Mean Squared Error:', mean_squared_error(test_y2, y_pred2))
print('R^2 Score:', r2_score(test_y2, y_pred2))
# Out:
# Mean Squared Error: 0.030647730986361258
# R^2 Score: 0.4545709909725647

# %% [markdown]
# we need to up grade to plonumyal linear regeression

# %%
diabetes_df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
# Add the target variable to the DataFrame
diabetes_df['target'] = diabetes.target
# Now you can calculate the correlation matrix
diabetes_df.corr()
# Out:
#              age       sex       bmi        bp        s1        s2        s3  \
# age     1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex     0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi     0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp      0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1      0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2      0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3     -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4      0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5      0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6      0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# target  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
# ...

# %%
drop=['age','s1','s2','sex']

# %%
diabetes_df = diabetes_df.drop(columns=drop, axis=1)

# %%
diabetes_df.head(5)
# Out:
#         bmi        bp        s3        s4        s5        s6  target
# 0  0.061696  0.021872 -0.043401 -0.002592  0.019907 -0.017646   151.0
# 1 -0.051474 -0.026328  0.074412 -0.039493 -0.068332 -0.092204    75.0
# 2  0.044451 -0.005670 -0.032356 -0.002592  0.002861 -0.025930   141.0
# 3 -0.011595 -0.036656 -0.036038  0.034309  0.022688 -0.009362   206.0
# 4 -0.036385  0.021872  0.008142 -0.002592 -0.031988 -0.046641   135.0

# %%
X= diabetes_df.drop('target', axis=1)
Y=  diabetes_df['target']
train_x2, test_x2, train_y2, test_y2 = train_test_split(X, Y, test_size=0.20, random_state=43, shuffle=True)
train_x2.shape, train_y2.shape
# Out:
# ((353, 6), (353,))

# %%
scaler_X = MinMaxScaler()  # Create a scaler for X
train_x2 = scaler_X.fit_transform(train_x2)  # Fit and transform training data
test_x2 = scaler_X.transform(test_x2)
# Create a separate scaler for Y
scaler_Y = MinMaxScaler()

# Reshape Y for scaling (MinMaxScaler expects 2D input)
train_y2 = train_y2.values.reshape(-1, 1)
test_y2 = test_y2.values.reshape(-1, 1)

# Fit and transform training target data
train_y2 = scaler_Y.fit_transform(train_y2)

# Transform test target data using the same scale
test_y2 = scaler_Y.transform(test_y2)

# %%
le_improved = LinearRegression()
le_improved.fit(train_x2, train_y2)
y_pred2 = le_improved.predict(test_x2)

# %%
print('Mean Squared Error:', mean_squared_error(test_y2, y_pred2))
print('R^2 Score:', r2_score(test_y2, y_pred2))
# Out:
# Mean Squared Error: 0.029969959080699573
# R^2 Score: 0.4666331060771446

# %%
X= diabetes_df.drop('target', axis=1)
Y=  diabetes_df['target']

# %%
poly= PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_poly, Y, test_size=0.2, random_state=42
)

# %%
scaler_X = MinMaxScaler()
X_train = scaler_X.fit_transform(X_train)
X_test = scaler_X.transform(X_test)

# %%
scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(y_train.reshape(-1, 1))
y_test = scaler_y.transform(y_test.values.reshape(-1, 1))

# %%
poly_reg = LinearRegression()
poly_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = poly_reg.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 26426.102902255407
# R-squared: -3.987796529167796
